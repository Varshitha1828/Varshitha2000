# %% [markdown]
# <a href="https://colab.research.google.com/github/Varshitha1828/Varshitha2000/blob/main/Internship_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np                  # importing the dataset to colab
import pandas as pd
df = pd.read_csv('/content/Fifa Olympics dataset.csv')
df
# Out:
#        Wage (€)  Value (€)               Name  Age Nationality  Overall  \
# 0        565000   95500000  Cristiano Ronaldo   32    Portugal       94
# 1        565000  105000000           L. Messi   30   Argentina       93
# 2        280000  123000000             Neymar   25      Brazil       92
# 3        510000   97000000          L. Suárez   30     Uruguay       92
# 4        230000   61000000           M. Neuer   31     Germany       92
# ...         ...        ...                ...  ...         ...      ...
# 17976      1000      50000          A. Kelsey   17     England       46
# 17977      1000          0      B. Richardson   47     England       46
# 17978      1000      60000           J. Young   17    Scotland       46
# 17979      1000      60000       J. Lundstram   18     England       46
# 17980      1000      50000          L. Sackey   18       Ghana       46
#
#        Potential                 Club  Special  Acceleration  ...    RB   RCB  \
# ...

# %%
df.shape   # we can know how many rows and columns are there
# Out:
# (17981, 71)

# %%
df.head()    # first 5 rows
# Out:
#    Wage (€)  Value (€)               Name  Age Nationality  Overall  \
# 0    565000   95500000  Cristiano Ronaldo   32    Portugal       94
# 1    565000  105000000           L. Messi   30   Argentina       93
# 2    280000  123000000             Neymar   25      Brazil       92
# 3    510000   97000000          L. Suárez   30     Uruguay       92
# 4    230000   61000000           M. Neuer   31     Germany       92
#
#    Potential                 Club  Special  Acceleration  ...    RB   RCB  \
# 0         94       Real Madrid CF     2228          89.0  ...  61.0  53.0
# 1         93         FC Barcelona     2154          92.0  ...  57.0  45.0
# 2         94  Paris Saint-Germain     2100          94.0  ...  59.0  46.0
# 3         92         FC Barcelona     2291          88.0  ...  64.0  58.0
# 4         92     FC Bayern Munich     1493          58.0  ...   NaN   NaN
#
#     RCM   RDM    RF    RM    RS    RW   RWB    ST
# 0  82.0  62.0  91.0  89.0  92.0  91.0  66.0  92.0
# ...

# %%
df.tail()       # last 5 rows
# Out:
#        Wage (€)  Value (€)           Name  Age Nationality  Overall  \
# 17976      1000      50000      A. Kelsey   17     England       46
# 17977      1000          0  B. Richardson   47     England       46
# 17978      1000      60000       J. Young   17    Scotland       46
# 17979      1000      60000   J. Lundstram   18     England       46
# 17980      1000      50000      L. Sackey   18       Ghana       46
#
#        Potential               Club  Special  Acceleration  ...    RB   RCB  \
# 17976         63  Scunthorpe United      755          24.0  ...   NaN   NaN
# 17977         46  Wycombe Wanderers      832          25.0  ...   NaN   NaN
# 17978         61       Swindon Town     1194          66.0  ...  31.0  28.0
# 17979         64    Crewe Alexandra     1302          57.0  ...  47.0  46.0
# 17980         64  Scunthorpe United     1031          48.0  ...  40.0  45.0
#
#         RCM   RDM    RF    RM    RS    RW   RWB    ST
# ...

# %%
df.info()           # to know the information about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17981 entries, 0 to 17980
# Data columns (total 71 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Wage (€)             17981 non-null  int64
#  1   Value (€)            17981 non-null  int64
#  2   Name                 17981 non-null  object
#  3   Age                  17981 non-null  int64
#  4   Nationality          17981 non-null  object
#  5   Overall              17981 non-null  int64
#  6   Potential            17981 non-null  int64
#  7   Club                 17733 non-null  object
#  8   Special              17981 non-null  int64
#  9   Acceleration         17897 non-null  float64
#  10  Aggression           17913 non-null  float64
#  11  Agility              17910 non-null  float64
#  12  Balance              17924 non-null  float64
#  13  Ball control         17840 non-null  float64
#  14  Composure            17887 non-null  float64
# ...

# %%
df.isnull()          # to know how many nulls
# Out:
#        Wage (€)  Value (€)   Name    Age  Nationality  Overall  Potential  \
# 0         False      False  False  False        False    False      False
# 1         False      False  False  False        False    False      False
# 2         False      False  False  False        False    False      False
# 3         False      False  False  False        False    False      False
# 4         False      False  False  False        False    False      False
# ...         ...        ...    ...    ...          ...      ...        ...
# 17976     False      False  False  False        False    False      False
# 17977     False      False  False  False        False    False      False
# 17978     False      False  False  False        False    False      False
# 17979     False      False  False  False        False    False      False
# 17980     False      False  False  False        False    False      False
#
#         Club  Special  Acceleration  ...     RB    RCB    RCM    RDM     RF  \
# ...

# %%
df.isnull().sum()       # to know how many nulls and their sum
# Out:
# Wage (€)          0
# Value (€)         0
# Name              0
# Age               0
# Nationality       0
#                ...
# RM             2029
# RS             2029
# RW             2029
# RWB            2029
# ST             2029
# Length: 71, dtype: int64

# %%
df.sample(3)           # randomly 3 rows
# Out:
#       Wage (€)  Value (€)             Name  Age     Nationality  Overall  \
# 3904      7000    1800000    Kwoun Sun Tae   32  Korea Republic       72
# 8333      7000    1200000     R. Lundqvist   20          Sweden       67
# 3945      8000    2900000  A. Mierzejewski   30          Poland       72
#
#       Potential             Club  Special  Acceleration  ...    RB   RCB  \
# 3904         72  Kashima Antlers     1206          39.0  ...   NaN   NaN
# 8333         77              PSV     1673          76.0  ...  52.0  46.0
# 3945         72        Sydney FC     1877          76.0  ...  55.0  51.0
#
#        RCM   RDM    RF    RM    RS    RW   RWB    ST
# 3904   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 8333  61.0  51.0  65.0  65.0  63.0  66.0  54.0  63.0
# 3945  68.0  58.0  72.0  72.0  71.0  72.0  58.0  71.0
#
# [3 rows x 71 columns]

# %%
df['Value (€)'].describe()           # to know about the statistics
# Out:
# count    1.798100e+04
# mean     2.385390e+06
# std      5.353970e+06
# min      0.000000e+00
# 25%      3.000000e+05
# 50%      6.750000e+05
# 75%      2.100000e+06
# max      1.230000e+08
# Name: Value (€), dtype: float64

# %%
import seaborn as sns                            # plottimg of a graph
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
sns.boxplot(x=df['Value (€)'])
plt.title('BoxPlot of Values')
plt.xlabel('Values')
plt.grid('True')
plt.show()

# %%
df['GK kicking'].describe()
# Out:
# count    17962.000000
# mean        16.344171
# std         16.548405
# min          1.000000
# 25%          8.000000
# 50%         11.000000
# 75%         14.000000
# max         95.000000
# Name: GK kicking, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
sns.boxplot(x=df['GK kicking'])
plt.title('Boxplot of Kicking')
plt.xlabel('kicking')
plt.grid('True')
plt.show()

# %%
df['GK handling'].describe()
# Out:
# count    17954.000000
# mean        16.444135
# std         16.928068
# min          1.000000
# 25%          8.000000
# 50%         11.000000
# 75%         14.000000
# max         91.000000
# Name: GK handling, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
sns.boxplot(x=df['GK handling'])
plt.title('Boxplot of Handling')
plt.xlabel('handling')
plt.grid('True')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
sns.boxplot(x=df['GK positioning'])
plt.title('Boxplot of Position')
plt.xlabel('Positioning')
plt.grid('True')
plt.show()

# %%
df['Acceleration'].value_counts()              # count of values
# Out:
# Acceleration
# 68.0    706
# 67.0    639
# 69.0    625
# 74.0    605
# 66.0    600
#        ...
# 14.0      4
# 96.0      3
# 13.0      2
# 12.0      2
# 11.0      2
# Name: count, Length: 86, dtype: int64

# %%
df['Age'].value_counts()
# Out:
# Age
# 25    1522
# 23    1394
# 24    1334
# 22    1324
# 21    1286
# 20    1245
# 26    1202
# 27    1152
# 29    1121
# 19    1069
# 28    1051
# 30     804
# 18     672
# 31     671
# 33     617
# 32     506
# 34     272
# 17     258
# 35     191
# 36     136
# 37      69
# 38      36
# 39      20
# 16      13
# 40       8
# 41       3
# 44       2
# 43       2
# 47       1
# Name: count, dtype: int64

# %%
df['ST'] = df['ST'].fillna(0)                # filling the particular columns with 0
df['CAM'] = df['CAM'].fillna(0)
df['CDM'] = df['CDM'].fillna(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17981 entries, 0 to 17980
# Data columns (total 71 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Wage (€)             17981 non-null  int64
#  1   Value (€)            17981 non-null  int64
#  2   Name                 17981 non-null  object
#  3   Age                  17981 non-null  int64
#  4   Nationality          17981 non-null  object
#  5   Overall              17981 non-null  int64
#  6   Potential            17981 non-null  int64
#  7   Club                 17733 non-null  object
#  8   Special              17981 non-null  int64
#  9   Acceleration         17897 non-null  float64
#  10  Aggression           17913 non-null  float64
#  11  Agility              17910 non-null  float64
#  12  Balance              17924 non-null  float64
#  13  Ball control         17840 non-null  float64
#  14  Composure            17887 non-null  float64
# ...

# %%
top_players = df.sort_values(by='Overall', ascending=False).head(5)
top_players_info = top_players[['Name', 'Overall', 'Nationality', 'Club']]

# %%
print("\nTop 5 Players:")             # top 5 players
print(top_players_info)
# Out:
# Top 5 Players:
#                 Name  Overall Nationality                 Club
# 0  Cristiano Ronaldo       94    Portugal       Real Madrid CF
# 1           L. Messi       93   Argentina         FC Barcelona
# 2             Neymar       92      Brazil  Paris Saint-Germain
# 3          L. Suárez       92     Uruguay         FC Barcelona
# 4           M. Neuer       92     Germany     FC Bayern Munich
